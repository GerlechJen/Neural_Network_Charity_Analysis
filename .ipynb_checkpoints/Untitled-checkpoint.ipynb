# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31984\4207446018.py in <module>
#       3 from sklearn.preprocessing import StandardScaler,OneHotEncoder
#       4 import pandas as pd
# ----> 5 import tensorflow as tf
#       6
#       7 #  Import and read the charity_data.csv.
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\__init__.py in <module>
#      49 from ._api.v2 import autograph
#      50 from ._api.v2 import bitwise
# ---> 51 from ._api.v2 import compat
#      52 from ._api.v2 import config
#      53 from ._api.v2 import data
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\__init__.py in <module>
#      35 import sys as _sys
#      36
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py in <module>
#      28 from . import autograph
#      29 from . import bitwise
# ---> 30 from . import compat
#      31 from . import config
#      32 from . import data
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py in <module>
#      35 import sys as _sys
#      36
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py in <module>
#      45 from tensorflow._api.v2.compat.v1 import layers
#      46 from tensorflow._api.v2.compat.v1 import linalg
# ---> 47 from tensorflow._api.v2.compat.v1 import lite
#      48 from tensorflow._api.v2.compat.v1 import logging
#      49 from tensorflow._api.v2.compat.v1 import lookup
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\__init__.py in <module>
#       7
#       8 from . import constants
# ----> 9 from . import experimental
#      10 from tensorflow.lite.python.lite import Interpreter
#      11 from tensorflow.lite.python.lite import OpHint
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from . import authoring
#       9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer
#      10 from tensorflow.lite.python.lite import OpResolverType
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\authoring\__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow.lite.python.authoring.authoring import compatible
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\lite\python\authoring\authoring.py in <module>
#      41
#      42 # pylint: disable=g-import-not-at-top
# ---> 43 from tensorflow.lite.python import convert
#      44 from tensorflow.lite.python import lite
#      45 from tensorflow.lite.python.metrics import converter_error_data_pb2
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\lite\python\convert.py in <module>
#      26
#      27 from tensorflow.lite.python import lite_constants
# ---> 28 from tensorflow.lite.python import util
#      29 from tensorflow.lite.python import wrap_toco
#      30 from tensorflow.lite.python.convert_phase import Component
#
# ~\anaconda3\envs\mlenv\lib\site-packages\tensorflow\lite\python\util.py in <module>
#      23 from six.moves import range
#      24
# ---> 25 import flatbuffers
#      26 from tensorflow.core.protobuf import config_pb2 as _config_pb2
#      27 from tensorflow.core.protobuf import graph_debug_info_pb2
#
# ModuleNotFoundError: No module named 'flatbuffers'
